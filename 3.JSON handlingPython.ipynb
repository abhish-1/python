# %%
import json

# %%
#load the data
def load_data(filename.txt):
    with open(filename.txt, "r") as f:
        data = json.load(f)

        return data

# %%
#Cleaning & structure the data -> duplicate, missing, irregularities.
def cleanData():
    textToNum = {"one":1, "two":2, "three":3, "four":4, "five":5}
    ans = []
    uniqueUser = set()
    for users in data:
        rawRating = str(user["rating"]).strip().lower()
        if(rawRating in textToNum):
            rawRating=textToNum(rawRating)
            user["rating"]=rawRating


        #Missing values
        age=users.get("age")  # get function gets you the val or a none.
        if (age = None)
            users["age"] = null

        #duplication
        if(users["name"].strip() in uniqueUser):
            continue
        uniqueUser.add(users["name"])
        ans.append(users)
        
    return ans

# %%
#operation on data
def getInsights(users):
    val =0
    for user in data:
        val+=float(users["rating"])
    avgRating = val/len(data)
